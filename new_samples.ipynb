# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

import os
import torch
import argparse
import yaml
from numba import cuda

from helpers.density_estimator import DensityEstimator
from helpers.ANODE_training_utils import train_ANODE, plot_ANODE_losses
from helpers.data_transforms import clean_data
from helpers.physics_functions import get_bins, get_bins_for_scan, curve_fit_m_inv, bkg_fit_cubic, bkg_fit_quintic, bkg_fit_septic
from helpers.plotting import *
from helpers.evaluation import *
from helpers.flow_sampling import *
# Out:
# /global/homes/r/rmastand/.local/lib/python3.8/site-packages/zfit/__init__.py:63: UserWarning: TensorFlow warnings are by default suppressed by zfit. In order to show them, set the environment variable ZFIT_DISABLE_TF_WARNINGS=0. In order to suppress the TensorFlow warnings AND this warning, set ZFIT_DISABLE_TF_WARNINGS=1.
#   warnings.warn(

# %%
bkg_fit_type = "quintic"
num_bins_SR = 12

if bkg_fit_type == "cubic": bkg_fit_function = bkg_fit_cubic
elif bkg_fit_type == "quintic": bkg_fit_function = bkg_fit_quintic
elif bkg_fit_type == "septic": bkg_fit_function = bkg_fit_septic

use_inner_bands = False
if use_inner_bands: bands = ["SBL", "IBL", "SR", "IBH", "SBH"]
else: bands = ["SBL", "SR", "SBH"]

train_samesign = True
if train_samesign: samesign_id = "SS"
else: samesign_id = "OS"

feature_id = "mix_2"
configs ="CATHODE_8"
feature_list = "dimu_pt,mu0_ip3d,mu1_ip3d,dimu_mass"
    
feature_set = [f for f in feature_list.split(",")]
print(f"Using feature set {feature_set}")
num_features = len(feature_set) - 1 # context doesn't count
# Out:
# Using feature set ['dimu_pt', 'mu0_ip3d', 'mu1_ip3d', 'dimu_mass']

# %%
import yaml
with open("workflow.yaml", "r") as file:
    workflow = yaml.safe_load(file)

working_dir = workflow["file_paths"]["working_dir"]
processed_data_dir = workflow["file_paths"]["data_storage_dir"] +"/projects/"+workflow["analysis_keywords"]["name"]+"/processed_data"
path_to_config_file = f"{working_dir}/configs/{configs}.yml"


# computing
device = cuda.get_current_device()
device.reset()
torch.set_num_threads(2)
device = torch.device( "cuda" if torch.cuda.is_available() else "cpu")
print( "Using device: " + str( device ), flush=True)
# Out:
# Using device: cuda

# %% [markdown]
# # load in the data -- this is used to fit to the SB / SR

# %%
data_dict = {}

# dataset for the bump hunt only
with open(f"{processed_data_dir}/bootstrap0_{samesign_id}_test_band_data", "rb") as ifile:
    test_data_dict = pickle.load(ifile)

print(f"{processed_data_dir}/bootstrap0_{samesign_id}_test_band_data", "rb")
for b in bands:
    num_events_band = test_data_dict[b]["dimu_mass"].shape[0]
    data_dict[b] = np.empty((num_events_band, num_features+1))
    for i, feat in enumerate(feature_set):
        data_dict[b][:,i] = test_data_dict[b][feat].reshape(-1,1).reshape(-1,)
    print("{b} data has shape {length}.".format(b = b, length = data_dict[b].shape))
# Out:
# /global/cfs/cdirs/m3246/rmastand/dimuonAD//projects/upsilon_iso_12_03/processed_data/bootstrap0_SS_test_band_data rb
# SBL data has shape (3868, 4).
# SR data has shape (989, 4).
# SBH data has shape (2311, 4).

# %%
data_dict["SBL"] = clean_data(data_dict["SBL"])
data_dict["SBH"] = clean_data(data_dict["SBH"])

# to draw peakless samples from the SR, we need to first do a bkg fit in the SB
masses_to_fit = np.hstack((data_dict["SBL"][:,-1], data_dict["SBH"][:,-1]))


# for a single window, we can define the SR / SB bins on the fly
print("Defining bins on the fly...")
SB_left, SR_left = np.min(data_dict["SBL"][:,-1].reshape(-1)),  np.max(data_dict["SBL"][:,-1].reshape(-1))
SR_right, SB_right = np.min(data_dict["SBH"][:,-1].reshape(-1)),  np.max(data_dict["SBH"][:,-1].reshape(-1))
plot_bins_all, plot_bins_SR, plot_bins_left, plot_bins_right, plot_centers_all, plot_centers_SR, plot_centers_SB = get_bins(SR_left, SR_right, SB_left, SB_right, binning="linear", num_bins_SR=num_bins_SR)
x = np.linspace(SB_left, SB_right, 100) # plot curve fit

popt_0, _, _, _, _ = curve_fit_m_inv(masses_to_fit, bkg_fit_type, SR_left, SR_right, plot_bins_left, plot_bins_right, plot_centers_SB)
    
plt.figure(figsize = (7,5))
plt.plot(x, bkg_fit_function(x, *popt_0), lw = 3, linestyle = "dashed", label = "SB fit")
plt.hist(masses_to_fit, bins = plot_bins_all, lw = 2, histtype = "step", density = False, label = "SB data") 

 
plt.legend()
plt.show()
# Out:
# Defining bins on the fly...

# %% [markdown]
# Load in the flows and generate samples

# %%
if train_samesign: num_samples = [1433,1433,1434,1434,1434]
else: num_samples = [2466,2466,2466,2467,2467]


flow_training_dir = workflow["file_paths"]["data_storage_dir"] +"/projects/" + workflow["analysis_keywords"]["name"]+f"/models/bootstrap0_{samesign_id}/{feature_id}/{configs}/"


bootstrap_start, bootstrap_stop = 6, 101

sampled_features = {i:[] for i in range(bootstrap_start, bootstrap_stop)}

for i in [6,7,8,9,10]: # flow seeds to read in


    # load in the best flow model
    loc_flow_training_dir = f"{flow_training_dir}/seed{i}"
    train_losses = np.load(os.path.join(loc_flow_training_dir, f"flow_train_losses.npy"))
    val_losses = np.load(os.path.join(loc_flow_training_dir, f"flow_val_losses.npy"))
    best_epoch = np.nanargmin(val_losses) - 1
    model_path = f"{loc_flow_training_dir}/flow_epoch_{best_epoch}.par"
    eval_model = DensityEstimator(path_to_config_file, num_features, eval_mode=True,load_path=model_path,device=device, verbose=False,bound=False)

    for bs in range(bootstrap_start, bootstrap_stop):
        if bs % 20 == 0:
            print(f"Bootstrapping {bs}")

        torch.manual_seed(bs)
        np.random.seed(bs)
    
        mass_samples = get_mass_samples(SB_left, SB_right, bkg_fit_type, num_samples[i-6], popt_0)
        feature_samples = get_flow_samples(eval_model, mass_samples) 
        sampled_features[bs].append(feature_samples)
# Out:
# DensityEstimator has 3912 parameters
# Loading model parameters from /global/cfs/cdirs/m3246/rmastand/dimuonAD//projects/upsilon_iso_12_03/models/bootstrap0_SS/mix_2/CATHODE_8//seed6/flow_epoch_240.par
# Bootstrapping 20
# Bootstrapping 40
# Bootstrapping 60
# Bootstrapping 80
# Bootstrapping 100
# DensityEstimator has 3912 parameters
# Loading model parameters from /global/cfs/cdirs/m3246/rmastand/dimuonAD//projects/upsilon_iso_12_03/models/bootstrap0_SS/mix_2/CATHODE_8//seed7/flow_epoch_351.par
# Bootstrapping 20
# Bootstrapping 40
# Bootstrapping 60
# Bootstrapping 80
# Bootstrapping 100
# DensityEstimator has 3912 parameters
# Loading model parameters from /global/cfs/cdirs/m3246/rmastand/dimuonAD//projects/upsilon_iso_12_03/models/bootstrap0_SS/mix_2/CATHODE_8//seed8/flow_epoch_337.par
# Bootstrapping 20
# Bootstrapping 40
# Bootstrapping 60
# Bootstrapping 80
# Bootstrapping 100
# DensityEstimator has 3912 parameters
# Loading model parameters from /global/cfs/cdirs/m3246/rmastand/dimuonAD//projects/upsilon_iso_12_03/models/bootstrap0_SS/mix_2/CATHODE_8//seed9/flow_epoch_171.par
# Bootstrapping 20
# Bootstrapping 40
# Bootstrapping 60
# Bootstrapping 80
# Bootstrapping 100
# DensityEstimator has 3912 parameters
# Loading model parameters from /global/cfs/cdirs/m3246/rmastand/dimuonAD//projects/upsilon_iso_12_03/models/bootstrap0_SS/mix_2/CATHODE_8//seed10/flow_epoch_137.par
# Bootstrapping 20
# Bootstrapping 40
# Bootstrapping 60
# Bootstrapping 80
# Bootstrapping 100

# %%
fig, ax = plt.subplots(1, 4, figsize = (12, 3))

for bs in range(bootstrap_start, bootstrap_stop):
    sampled_features[bs] = np.vstack(sampled_features[bs])
    for j in range(4):
        ax[j].hist(sampled_features[bs][:,j], bins = np.linspace(-4,4, 40), histtype = "step", label = bs)

plt.legend()
plt.show()

# %%
for bs in range(bootstrap_start, bootstrap_stop):  
    in_SR = (sampled_features[bs][:,-1] >= SR_left) & (sampled_features[bs][:,-1] <= SR_right)
    in_SBL = (sampled_features[bs][:,-1] < SR_left)
    in_SBH = (sampled_features[bs][:,-1] > SR_right)

    flow_dict_SR, flow_dict_SBL, flow_dict_SBH = {},{},{}
    
    for i,feat in enumerate(feature_set):
        
        flow_dict_SR[feat] = sampled_features[bs][in_SR][:,i].reshape(-1,1)
        flow_dict_SBL[feat] = sampled_features[bs][in_SBL][:,i].reshape(-1,1)
        flow_dict_SBH[feat] = sampled_features[bs][in_SBH][:,i].reshape(-1,1)

    flow_dict = {"SR":flow_dict_SR, "SBL":flow_dict_SBL, "SBH":flow_dict_SBH}


    with open(f"/global/cfs/cdirs/m3246/rmastand/dimuonAD/projects/upsilon_iso_12_03/processed_data/bkg_samples/bootstrap{bs}_{samesign_id}_test_band_data", "wb") as ofile:
        pickle.dump(flow_dict, ofile)

# %%
for i in range(545, 1001):
    print(f"python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd {i} -seeds 1,2,3,4,5 -run_null")
    #print f"python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd {i} -seeds 1,2,3,4,5 -run_null -train_samesign"
# Out:
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 545 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 546 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 547 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 548 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 549 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 550 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 551 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 552 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 553 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 554 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 555 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 556 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 557 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 558 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 559 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 560 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 561 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 562 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 563 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 564 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 565 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 566 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 567 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 568 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 569 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 570 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 571 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 572 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 573 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 574 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 575 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 576 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 577 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 578 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 579 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 580 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 581 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 582 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 583 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 584 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 585 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 586 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 587 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 588 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 589 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 590 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 591 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 592 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 593 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 594 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 595 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 596 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 597 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 598 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 599 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 600 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 601 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 602 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 603 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 604 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 605 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 606 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 607 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 608 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 609 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 610 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 611 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 612 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 613 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 614 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 615 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 616 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 617 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 618 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 619 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 620 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 621 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 622 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 623 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 624 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 625 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 626 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 627 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 628 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 629 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 630 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 631 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 632 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 633 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 634 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 635 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 636 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 637 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 638 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 639 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 640 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 641 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 642 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 643 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 644 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 645 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 646 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 647 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 648 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 649 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 650 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 651 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 652 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 653 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 654 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 655 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 656 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 657 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 658 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 659 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 660 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 661 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 662 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 663 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 664 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 665 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 666 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 667 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 668 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 669 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 670 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 671 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 672 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 673 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 674 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 675 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 676 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 677 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 678 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 679 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 680 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 681 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 682 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 683 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 684 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 685 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 686 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 687 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 688 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 689 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 690 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 691 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 692 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 693 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 694 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 695 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 696 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 697 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 698 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 699 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 700 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 701 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 702 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 703 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 704 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 705 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 706 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 707 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 708 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 709 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 710 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 711 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 712 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 713 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 714 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 715 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 716 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 717 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 718 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 719 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 720 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 721 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 722 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 723 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 724 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 725 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 726 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 727 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 728 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 729 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 730 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 731 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 732 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 733 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 734 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 735 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 736 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 737 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 738 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 739 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 740 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 741 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 742 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 743 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 744 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 745 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 746 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 747 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 748 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 749 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 750 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 751 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 752 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 753 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 754 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 755 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 756 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 757 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 758 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 759 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 760 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 761 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 762 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 763 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 764 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 765 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 766 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 767 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 768 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 769 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 770 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 771 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 772 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 773 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 774 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 775 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 776 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 777 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 778 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 779 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 780 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 781 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 782 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 783 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 784 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 785 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 786 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 787 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 788 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 789 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 790 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 791 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 792 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 793 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 794 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 795 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 796 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 797 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 798 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 799 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 800 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 801 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 802 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 803 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 804 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 805 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 806 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 807 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 808 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 809 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 810 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 811 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 812 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 813 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 814 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 815 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 816 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 817 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 818 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 819 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 820 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 821 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 822 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 823 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 824 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 825 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 826 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 827 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 828 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 829 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 830 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 831 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 832 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 833 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 834 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 835 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 836 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 837 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 838 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 839 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 840 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 841 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 842 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 843 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 844 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 845 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 846 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 847 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 848 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 849 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 850 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 851 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 852 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 853 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 854 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 855 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 856 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 857 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 858 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 859 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 860 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 861 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 862 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 863 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 864 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 865 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 866 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 867 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 868 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 869 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 870 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 871 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 872 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 873 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 874 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 875 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 876 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 877 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 878 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 879 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 880 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 881 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 882 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 883 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 884 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 885 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 886 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 887 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 888 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 889 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 890 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 891 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 892 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 893 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 894 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 895 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 896 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 897 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 898 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 899 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 900 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 901 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 902 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 903 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 904 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 905 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 906 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 907 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 908 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 909 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 910 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 911 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 912 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 913 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 914 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 915 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 916 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 917 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 918 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 919 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 920 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 921 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 922 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 923 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 924 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 925 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 926 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 927 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 928 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 929 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 930 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 931 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 932 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 933 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 934 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 935 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 936 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 937 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 938 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 939 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 940 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 941 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 942 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 943 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 944 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 945 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 946 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 947 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 948 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 949 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 950 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 951 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 952 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 953 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 954 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 955 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 956 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 957 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 958 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 959 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 960 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 961 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 962 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 963 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 964 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 965 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 966 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 967 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 968 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 969 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 970 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 971 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 972 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 973 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 974 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 975 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 976 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 977 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 978 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 979 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 980 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 981 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 982 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 983 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 984 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 985 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 986 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 987 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 988 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 989 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 990 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 991 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 992 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 993 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 994 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 995 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 996 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 997 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 998 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 999 -seeds 1,2,3,4,5 -run_null
# python 07_run_bump_hunt.py -fid mix_2 -ne 100 -fit quintic -n_bins 12 -bd 1000 -seeds 1,2,3,4,5 -run_null
